# %%
pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (1.10.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (5.5.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash) (8.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: colorama in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: six in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: brotli in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from flask-compress->dash) (1.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash_bootstrap_components
# Out:
# Requirement already satisfied: dash_bootstrap_components in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (1.0.2)
# Requirement already satisfied: dash>=2.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.10.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.5.0)
# Requirement already satisfied: click>=7.1.2 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (8.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: colorama in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: six in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (8.0.1)
# Requirement already satisfied: brotli in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from flask-compress->dash>=2.0.0->dash_bootstrap_components) (1.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (5.5.0)
# Requirement already satisfied: six in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly.express
# Out:
# Collecting plotly.expressNote: you may need to restart the kernel to use updated packages.
#
#   Using cached plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.13.2-cp38-cp38-win_amd64.whl (9.1 MB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly.express) (1.3.3)
# Collecting patsy>=0.5
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly.express) (5.5.0)
# Requirement already satisfied: numpy>=1.11 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly.express) (1.20.3)
# Requirement already satisfied: scipy>=0.18 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly.express) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from pandas>=0.20.0->plotly.express) (2021.1)
# Requirement already satisfied: six in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from plotly>=4.1.0->plotly.express) (8.0.1)
# Collecting packaging>=21.3
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->plotly.express) (2.4.7)
# Installing collected packages: patsy, packaging, statsmodels, plotly.express
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# Successfully installed packaging-21.3 patsy-0.5.2 plotly.express statsmodels-0.13.2

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (1.3.3)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytz>=2017.3 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
pip install pybase64
# Out:
# Collecting pybase64Note: you may need to restart the kernel to use updated packages.
#   Using cached pybase64-1.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Installing collected packages: pybase64
# Successfully installed pybase64-1.2.1

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\nikiforos\anaconda3\envs\thesis\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Imports
import dash
from dash import dcc
from dash import html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State
from dash.exceptions import PreventUpdate
import plotly.graph_objects as go
import  plotly.express as px
import pandas as pd
import base64
#Initialising the dash app
app = dash.Dash(__name__, external_stylesheets = [dbc.themes.BOOTSTRAP])

#Loading the data
df_1_16 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2016/Dataset_Y2016_map%20data.xlsx", sheet_name="Dataset_Y2016_map data")
df_2_16 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2016/Dataset_Y2016_map%20data.xlsx", sheet_name="Coordinates")

df_1_17 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2017/Dataset_Y2017_map%20data.xlsx", sheet_name="Dataset_Y2017_map data")
df_2_17 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2017/Dataset_Y2017_map%20data.xlsx", sheet_name="Sheet1")

# logo = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Simulated spatial distribution/Negative ESI mz=44.9996 RTI=932.2 rt=13.79.png"
# logo_base64 = base64.b64encode(open(logo, 'rb').read()).decode('ascii')
# src = 'data:image/png;base64,{}'.format(logo_base64)

app.layout = html.Div([
    html.Br([]),
    html.H1("EMBLAS-II: EU/UNDP project Improving Environmental Monitoting in the Black Sea", style = {"text-align": "center"}),
    html.H3("Non-target Screening Data", style = {"text-align": "center"}),

    dbc.Row([
        dbc.Col(
            # This is the Card for the control and the table
            dbc.Card([
                # Control Beginning
                    html.H5("Joint Black Sea Surveys"),
                    html.Br([]),
                    html.H6("Select (JBBS) year"),
                    dcc.Dropdown(
                        id = "year_dropdown", # These IDs are important for the callbacks
                        options = [{'label': "2016", 'value': "2016"},
                                   {'label': "2017", 'value': "2017"}],
                        style = {"padding-left": "24px"},
                        value = "2016" # default value
                    ),
                    html.Br([]),
                    html.H6("Select Source"),
                    dcc.Checklist(
                        id = "source_checklist",
                        options=[
                            {'label': "Danube", 'value': 'Danube'},
                            {'label': 'Dnieper', 'value': 'Dnieper'},
                            {'label': 'Unknown origin', 'value': 'Unknown origin'}
                        ],
                        labelStyle={'display': 'block'},
                        inputStyle={"margin-right": "12px"},
                        value=['Danube', "Dnieper", "Unknown origin"],
                        style = {"padding-left": "24px"},
                ),
                html.Br([]),
                html.H6("Filter Compounds"),
                dbc.Row(
                    [
                        dbc.Label("mz", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="mz_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                dbc.Row(
                    [
                        dbc.Label("RTI", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="rti_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                dbc.Row(
                    [
                        dbc.Label("rt", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="rt_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                html.Br([]),
                html.H6("Select Compound"),
                dcc.Dropdown(
                    id="compound_dropdown",
                    optionHeight=25,
                    style={"padding-left": "24px"},
                ),
            ], style = { "height": "600px",
                         "margin-right": "12px",
                         "margin-top": "24px",
                         "padding": "24px"})
            ,width= {"size":3}),
        dbc.Col([
            # This is the card for the pie chart
            dbc.Card(
                dbc.CardBody([
                    html.H5("Occurrence Map", style= {"text-align": "center"}),
                    html.Br([]),
                    dcc.Graph(
                        id="map",
                    )
                ]), style={
                           "height": "600px",
                           "margin-left": "12px",
                           "margin-right": "12px",
                           "margin-top": "24px",
                           }
            )],
            width=5),
        dbc.Col([
            # This is the card for the pie chart
            dbc.Card(
                dbc.CardBody([
                    html.H6("Simulated spatial distribution Ukranian shelf", style={"text-align": "center"}),
                    html.Img(
                        id = "img",
                        height=200,
                        style={"display": "block",
                               "margin-left": "auto",
                               "margin-right": "auto",
                               #"width": "50%",
                             }
                    ),
                    html.Br([]),
                    html.H6("HRMS/MS", style={"text-align": "center"}),
                    html.Div(
                        id="bar_chart",
                    )
                ]), style={
                    "height": "600px",
                    "margin-left": "12px",
                    "margin-top": "24px",
                }
            )],
            width=4),
    ]),
    html.Br([]),
    html.Br([]),
])


# #Create activity with Callbacks // The Output component will be changend depending on the input component
# @app.callback([
#     Output("source_checklist", "options"),
#     Output("source_checklist", "value")],
#     [Input("year_dropdown", "value")]
# )
# def table(year):
#     if year == "2016":
#         df = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Dataset_Y2016_map data.xlsx", sheet_name="Dataset_Y2016_map data")
#     elif year == "2017":
#         df = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Dataset_Y2017_map data.xlsx", sheet_name="Dataset_Y2017_map data")
#
#     values  = df["Predicted label"].unique()
#     options = [{"label": i, "value": i} for i in values]
#
#     return [options, values]


@app.callback([
    Output("compound_dropdown", "options"),
    Output("compound_dropdown", "value")],
    [Input("year_dropdown", "value"),
    Input("mz_input", "value"),
    Input("rti_input", "value"),
    Input("rt_input", "value"),
    Input("source_checklist", "value")]
)
def table(year, mz, rti, rt, sources):
    if year == "2016":
        df = df_1_16
    elif year == "2017":
        df = df_1_17

    df = df[df["Predicted label"].isin(sources)]

    if mz:
        df = df[df['Feature'].str.contains("mz=" + str(mz))]
    if rti:
        df = df[df['Feature'].str.contains("RTI=" + str(rti))]
    if rt:
        df = df[df['Feature'].str.contains("rt=" + str(rt))]

    options = [{"label": i, "value": i} for i in df["Feature"].unique()]
    value = df["Feature"].tolist()[0]

    return [options, value]


@app.callback(
    Output("map", "figure"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):

    if year == "2016":
        df_1 = df_1_16
        df_2 = df_2_16
    elif year == "2017":
        df_1 = df_1_17
        df_2 = df_2_17

    filtered_df_1 = df_1[df_1["Feature"] == compound]
    magnitude = filtered_df_1.values[0]
    df_2["Magnitude"] = magnitude[2:]
    fig = px.density_mapbox(df_2, lat='Latitude', lon='Longitude', z='Magnitude', radius=10,
                            center=dict(lat=43.5, lon=34), zoom=4,
                            mapbox_style="stamen-terrain")


    # fig = go.Figure(go.Densitymapbox(lat=df_2.Latitude, lon=df_2.Longitude, z=df_2.Magnitude))#, radius=10))
    # fig.update_layout(mapbox_style="stamen-terrain", mapbox_center_lon=34, mapbox_center_lat = 43.5, mapbox_zoom = 4, showlegend=False)

    fig.update_layout(margin={"t": 0, "b": 0, "l": 24, "r": 24},

                      # legend=dict(
                      #     orientation="h",
                      #     yanchor="bottom",
                      #     y=1.02,
                      #     xanchor="right",
                      #     x=1
                      # )
                      )

    return fig


@app.callback(
    Output("img", "src"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):
    if year == "2016":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2016/Simulated spatial distribution/" + compound + ".png"
    elif year == "2017":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2017/Simulated spatial distribution/" + compound + ".png"

    img_base64 = base64.b64encode(open(path, 'rb').read()).decode('ascii')
    src = 'data:image/png;base64,{}'.format(img_base64)

    return src


@app.callback(
    Output("bar_chart", "children"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):
    if year == "2016":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2016/HRMSMS/" + compound + ".csv"
    elif year == "2017":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2017/HRMSMS/" + compound + ".csv"

    try:
        df = pd.read_csv(path)

    except:
        return html.Div([html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Div("No data for this compound", style={"text-align": "center"})])

    fig = go.Figure([go.Bar(x=df.mz, y=df.rt)])
    fig.update_traces(marker_color='Grey', marker_line_color='Black') #,marker_line_width=1.5, opacity=0.6)
    fig.update_layout(plot_bgcolor='white',
                      height= 300,
                      margin={"t": 20, "b": 0, "l": 50, "r": 50},
                      legend={'font': {'family': "arial"}},
                      )

    fig.update_layout(legend=dict(
        font={'family': 'arial', 'size': 14, "color": "black"},
    ))

    fig.update_xaxes(title={'text': "Mass to charge ratio (m/z)", 'font': {'family': 'arial', 'size': 14, "color": "black"}},
                     showline=True, tickfont={'family': 'arial', 'size': 12, "color": "black"},
                     linewidth=1, linecolor='black', showgrid=False, mirror=True)
    fig.update_yaxes(title={'text': "Intensity (counts)", 'font': {'family': 'arial', 'size': 14, "color": "black"}},
                     showline=True, showgrid=False, gridwidth=0.5,gridcolor='lightgrey',
                     linewidth=1, linecolor='black', ticks='outside', tickfont={'family': 'arial', 'size': 12, "color": "black"},
                     mirror=True, rangemode="tozero")

    return html.Div([
                dbc.Button("Download CSV", id="btn_csv", style={"float": "right", "position": "relative", "z-index": "2", "margin-top": "25px", "margin-right": "60px"}),
                dcc.Download(id="download-dataframe-csv"),
                html.Br([]),html.Br([]),
                dcc.Graph(figure=fig,style={"margin-top": "-50px", "position": "relative", "z-index": "1"})
            ])


@app.callback(
    Output("download-dataframe-csv", "data"),
    Input("btn_csv", "n_clicks"),
    [State("compound_dropdown", "value"),
    State("year_dropdown", "value")], prevent_initial_call=True
)
def func(n_clicks, compound, year):
    if year == "2016":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2016/HRMSMS/" + compound + ".csv"
    elif year == "2017":
        path = "http://dsfp.chem.uoa.gr/BlackSea/Y2017/HRMSMS/" + compound + ".csv"

    df = pd.read_csv(path)
    return dcc.send_data_frame(df.to_csv, "Y2016/HRMSMS/" + compound + ".csv", index=False)


#Starting the app
if __name__ == '__main__':
     app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_17612/1199148599.py in <module>
#      15 #Loading the data
#      16 df_1_16 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2016/Dataset_Y2016_map%20data.xlsx", sheet_name="Dataset_Y2016_map data")
# ---> 17 df_2_16 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2016/Dataset_Y2016_map data.xlsx", sheet_name="Coordinates")
#      18
#      19 df_1_17 = pd.read_excel("http://dsfp.chem.uoa.gr/BlackSea/Y2017/Dataset_Y2017_map data.xlsx", sheet_name="Dataset_Y2017_map data")
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in http_open(self, req)
#    1381
#    1382     def http_open(self, req):
# -> 1383         return self.do_open(http.client.HTTPConnection, req)
#    1384
#    1385     http_request = AbstractHTTPHandler.do_request_
#
# ~\anaconda3\envs\Thesis\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352         try:
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#    1356             except OSError as err: # timeout error
#
# ~\anaconda3\envs\Thesis\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254                 encode_chunked=False):
#    1255         """Send a complete request to the server."""
# -> 1256         self._send_request(method, url, body, headers, encode_chunked)
#    1257
#    1258     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\anaconda3\envs\Thesis\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1265             skips['skip_accept_encoding'] = 1
#    1266
# -> 1267         self.putrequest(method, url, **skips)
#    1268
#    1269         # chunked encoding will happen if HTTP/1.1 is used and either
#
# ~\anaconda3\envs\Thesis\lib\http\client.py in putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1099
#    1100         url = url or '/'
# -> 1101         self._validate_path(url)
#    1102
#    1103         request = '%s %s %s' % (method, url, self._http_vsn_str)
#
# ~\anaconda3\envs\Thesis\lib\http\client.py in _validate_path(self, url)
#    1199         match = _contains_disallowed_url_pchar_re.search(url)
#    1200         if match:
# -> 1201             raise InvalidURL(f"URL can't contain control characters. {url!r} "
#    1202                              f"(found at least {match.group()!r})")
#    1203
#
# InvalidURL: URL can't contain control characters. '/BlackSea/Y2016/Dataset_Y2016_map data.xlsx' (found at least ' ')

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
