# %%
#Imports
import dash
from dash import dcc
from dash import html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State
from dash.exceptions import PreventUpdate
import plotly.graph_objects as go
import  plotly.express as px
import pandas as pd
import base64

# %%
#Initialising the dash app
app = dash.Dash(__name__, external_stylesheets = [dbc.themes.BOOTSTRAP])

#Loading the data
df_1_16 = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Dataset_Y2016_map data.xlsx", sheet_name="Dataset_Y2016_map data")
df_2_16 = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Dataset_Y2016_map data.xlsx", sheet_name="Coordinates")

df_1_17 = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Dataset_Y2017_map data.xlsx", sheet_name="Dataset_Y2017_map data")
df_2_17 = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Dataset_Y2017_map data.xlsx", sheet_name="Sheet1")

# logo = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Simulated spatial distribution/Negative ESI mz=44.9996 RTI=932.2 rt=13.79.png"
# logo_base64 = base64.b64encode(open(logo, 'rb').read()).decode('ascii')
# src = 'data:image/png;base64,{}'.format(logo_base64)

app.layout = html.Div([
    html.Br([]),
    html.H1("EMBLAS-II: EU/UNDP project Improving Environmental Monitoting in the Black Sea", style = {"text-align": "center"}),
    html.H3("Non-target Screening Data", style = {"text-align": "center"}),

    dbc.Row([
        dbc.Col(
            # This is the Card for the control and the table
            dbc.Card([
                # Control Beginning
                    html.H5("Joint Black Sea Surveys"),
                    html.Br([]),
                    html.H6("Select (JBBS) year"),
                    dcc.Dropdown(
                        id = "year_dropdown", # These IDs are important for the callbacks
                        options = [{'label': "2016", 'value': "2016"},
                                   {'label': "2017", 'value': "2017"}],
                        style = {"padding-left": "24px"},
                        value = "2016" # default value
                    ),
                    html.Br([]),
                    html.H6("Select Source"),
                    dcc.Checklist(
                        id = "source_checklist",
                        options=[
                            {'label': "Danube", 'value': 'Danube'},
                            {'label': 'Dnieper', 'value': 'Dnieper'},
                            {'label': 'Unknown origin', 'value': 'Unknown origin'}
                        ],
                        labelStyle={'display': 'block'},
                        inputStyle={"margin-right": "12px"},
                        value=['Danube', "Dnieper", "Unknown origin"],
                        style = {"padding-left": "24px"},
                ),
                html.Br([]),
                html.H6("Filter Compounds"),
                dbc.Row(
                    [
                        dbc.Label("mz", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="mz_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                dbc.Row(
                    [
                        dbc.Label("RTI", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="rti_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                dbc.Row(
                    [
                        dbc.Label("rt", width=4),
                        dbc.Col(
                            dbc.Input(
                                type="number", id="rt_input"
                            ),
                            width=8,
                        ),
                    ],
                    style={"padding-left": "24px"},
                    className="mb-3",
                ),
                html.Br([]),
                html.H6("Select Compound"),
                dcc.Dropdown(
                    id="compound_dropdown",
                    style={"padding-left": "24px"},
                ),
            ], style = { "height": "600px",
                         "margin-right": "12px",
                         "margin-top": "24px",
                         "padding": "24px"})
            ,width= {"size":4}),
        dbc.Col([
            # This is the card for the pie chart
            dbc.Card(
                dbc.CardBody([
                    html.H5("Occurence Map", style= {"text-align": "center"}),
                    html.Br([]),
                    dcc.Graph(
                        id="map",
                    )
                ]), style={
                           "height": "600px",
                           "margin-left": "12px",
                           "margin-right": "12px",
                           "margin-top": "24px",
                           }
            )],
            width=4),
        dbc.Col([
            # This is the card for the pie chart
            dbc.Card(
                dbc.CardBody([
                    html.H6("Simulated spatial distribution Ukranian shelf", style={"text-align": "center"}),
                    html.Img(
                        id = "img",
                        height=200,
                        style={"display": "block",
                               "margin-left": "auto",
                               "margin-right": "auto",
                               #"width": "50%",
                             }
                    ),
                    html.Br([]),
                    html.H6("HRMS/MS", style={"text-align": "center"}),
                    html.Div(
                        id="bar_chart",
                    )
                ]), style={
                    "height": "600px",
                    "margin-left": "12px",
                    "margin-top": "24px",
                }
            )],
            width=4),
    ]),
    html.Br([]),
    html.Br([]),
])


# #Create activity with Callbacks // The Output component will be changend depending on the input component
# @app.callback([
#     Output("source_checklist", "options"),
#     Output("source_checklist", "value")],
#     [Input("year_dropdown", "value")]
# )
# def table(year):
#     if year == "2016":
#         df = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Dataset_Y2016_map data.xlsx", sheet_name="Dataset_Y2016_map data")
#     elif year == "2017":
#         df = pd.read_excel("C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Dataset_Y2017_map data.xlsx", sheet_name="Dataset_Y2017_map data")
#
#     values  = df["Predicted label"].unique()
#     options = [{"label": i, "value": i} for i in values]
#
#     return [options, values]


@app.callback([
    Output("compound_dropdown", "options"),
    Output("compound_dropdown", "value")],
    [Input("year_dropdown", "value"),
    Input("mz_input", "value"),
    Input("rti_input", "value"),
    Input("rt_input", "value"),
    Input("source_checklist", "value")]
)
def table(year, mz, rti, rt, sources):
    if year == "2016":
        df = df_1_16
    elif year == "2017":
        df = df_1_17

    df = df[df["Predicted label"].isin(sources)]

    if mz:
        df = df[df['Feature'].str.contains("mz=" + str(mz))]
    if rti:
        df = df[df['Feature'].str.contains("RTI=" + str(rti))]
    if rt:
        df = df[df['Feature'].str.contains("rt=" + str(rt))]

    options = [{"label": i, "value": i} for i in df["Feature"].unique()]
    value = df["Feature"].tolist()[0]

    return [options, value]


@app.callback(
    Output("map", "figure"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):

    if year == "2016":
        df_1 = df_1_16
        df_2 = df_2_16
    elif year == "2017":
        df_1 = df_1_17
        df_2 = df_2_17

    filtered_df_1 = df_1[df_1["Feature"] == compound]
    magnitude = filtered_df_1.values[0]
    df_2["Magnitude"] = magnitude[2:]
    fig = px.density_mapbox(df_2, lat='Latitude', lon='Longitude', z='Magnitude', radius=10,
                            center=dict(lat=43.5, lon=34), zoom=4,
                            mapbox_style="stamen-terrain")


    # fig = go.Figure(go.Densitymapbox(lat=df_2.Latitude, lon=df_2.Longitude, z=df_2.Magnitude))#, radius=10))
    # fig.update_layout(mapbox_style="stamen-terrain", mapbox_center_lon=34, mapbox_center_lat = 43.5, mapbox_zoom = 4, showlegend=False)

    fig.update_layout(margin={"t": 0, "b": 0, "l": 24, "r": 24},

                      # legend=dict(
                      #     orientation="h",
                      #     yanchor="bottom",
                      #     y=1.02,
                      #     xanchor="right",
                      #     x=1
                      # )
                      )

    return fig


@app.callback(
    Output("img", "src"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):
    if year == "2016":
        path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Simulated spatial distribution/" + compound + ".png"
    elif year == "2017":
        path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/Simulated spatial distribution/" + compound + ".png"

    img_base64 = base64.b64encode(open(path, 'rb').read()).decode('ascii')
    src = 'data:image/png;base64,{}'.format(img_base64)

    return src


@app.callback(
    Output("bar_chart", "children"),
    [Input("compound_dropdown", "value")],
    [State("year_dropdown", "value")], prevent_initial_call = True
)
def graph1(compound, year):
    if year == "2016":
        path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/HRMSMS/" + compound + ".csv"
    elif year == "2017":
        path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2017/HRMSMS/" + compound + ".csv"

    try:
        df = pd.read_csv(path)

        print(df)
    except:
        return html.Div([html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Br([]), html.Div("No data for this compound", style={"text-align": "center"})])

    fig = go.Figure([go.Bar(x=df.mz, y=df.rt)])
    fig.update_traces(marker_color='Grey', marker_line_color='Black') #,marker_line_width=1.5, opacity=0.6)
    fig.update_layout(plot_bgcolor='white',
                      height= 300,
                      margin={"t": 20, "b": 0, "l": 50, "r": 50},
                      legend={'font': {'family': "arial"}},
                      )

    fig.update_layout(legend=dict(
        font={'family': 'arial', 'size': 14, "color": "black"},
    ))

    fig.update_xaxes(title={'text': "Mass to charge ratio (m/z)", 'font': {'family': 'arial', 'size': 14, "color": "black"}},
                     showline=True, tickfont={'family': 'arial', 'size': 12, "color": "black"},
                     linewidth=1, linecolor='black', showgrid=False, mirror=True)
    fig.update_yaxes(title={'text': "Intensity (counts)", 'font': {'family': 'arial', 'size': 14, "color": "black"}},
                     showline=True, showgrid=False, gridwidth=0.5,gridcolor='lightgrey',
                     linewidth=1, linecolor='black', ticks='outside', tickfont={'family': 'arial', 'size': 12, "color": "black"},
                     mirror=True, rangemode="tozero")

    return dcc.Graph(figure=fig)


#Starting the app
if __name__ == '__main__':
     app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#               mz    rt
# 0      45.034101   660
# 1      45.046642   104
# 2      51.029540    76
# 3      53.039136   124
# 4      55.017319  1584
# ...          ...   ...
# 1658  926.660634    56
# 1659  928.552604    72
# 1660  936.422029    60
# 1661  984.907467    52
# 1662  986.765712    52
#
# [1663 rows x 2 columns]
#               mz   rt
# 0      45.033002  208
# 1      46.035454   84
# 2      55.020091   52
# 3      55.053504  184
# 4      56.049808   92
# ...          ...  ...
# 1416  654.510798  100
# 1417  683.385578   72
# 1418  719.370887   56
# 1419  757.476269   56
# 1420  767.465669   56
#
# [1421 rows x 2 columns]
#               mz    rt
# 0      45.033193   196
# 1      55.054023    56
# 2      57.070091    68
# 3      58.063350    56
# 4      59.048570  1132
# ...          ...   ...
# 1675  652.436985    84
# 1676  699.448969   104
# 1677  726.856441    52
# 1678  732.308797    52
# 1679  897.603316    72
#
# [1680 rows x 2 columns]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
#               mz    rt
# 0      45.033193   196
# 1      55.054023    56
# 2      57.070091    68
# 3      58.063350    56
# 4      59.048570  1132
# ...          ...   ...
# 1675  652.436985    84
# 1676  699.448969   104
# 1677  726.856441    52
# 1678  732.308797    52
# 1679  897.603316    72
#
# [1680 rows x 2 columns]
#               mz   rt
# 0      45.033002  208
# 1      46.035454   84
# 2      55.020091   52
# 3      55.053504  184
# 4      56.049808   92
# ...          ...  ...
# 1416  654.510798  100
# 1417  683.385578   72
# 1418  719.370887   56
# 1419  757.476269   56
# 1420  767.465669   56
#
# [1421 rows x 2 columns]
#               mz    rt
# 0      45.034101   660
# 1      45.046642   104
# 2      51.029540    76
# 3      53.039136   124
# 4      55.017319  1584
# ...          ...   ...
# 1658  926.660634    56
# 1659  928.552604    72
# 1660  936.422029    60
# 1661  984.907467    52
# 1662  986.765712    52
#
# [1663 rows x 2 columns]
#              mz    rt
# 0     45.035005    88
# 1     53.037252    68
# 2     54.051083   132
# 3     55.017545    60
# 4     55.053712  1072
# ..          ...   ...
# 323  185.091026    56
# 324  193.006869    56
# 325  220.093336    52
# 326  277.568365    52
# 327  468.297073   128
#
# [328 rows x 2 columns]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
#              mz    rt
# 0     45.035005    88
# 1     53.037252    68
# 2     54.051083   132
# 3     55.017545    60
# 4     55.053712  1072
# ..          ...   ...
# 323  185.091026    56
# 324  193.006869    56
# 325  220.093336    52
# 326  277.568365    52
# 327  468.297073   128
#
# [328 rows x 2 columns]
#              mz   rt
# 0     45.035256  100
# 1     50.421511  120
# 2     51.023625  104
# 3     53.001628   64
# 4     53.038726   72
# ..          ...  ...
# 116  118.941779   68
# 117  125.106493   76
# 118  127.051654   80
# 119  146.030430   60
# 120  211.754033   72
#
# [121 rows x 2 columns]
#              mz   rt
# 0     53.038797  204
# 1     54.034027  176
# 2     55.017103  212
# 3     55.054506  532
# 4     56.050306  164
# ..          ...  ...
# 201  166.074791   56
# 202  175.049670  104
# 203  220.139789   72
# 204  257.133292   76
# 205  433.150387   68
#
# [206 rows x 2 columns]
#              mz   rt
# 0     45.036565  120
# 1     46.063375   96
# 2     51.024448  112
# 3     53.013038   68
# 4     53.038706  164
# ..          ...  ...
# 495  257.126901   60
# 496  259.141957   88
# 497  260.079795   60
# 498  262.103162  120
# 499  347.162057   68
#
# [500 rows x 2 columns]
#              mz   rt
# 0     44.978723   84
# 1     45.033018  632
# 2     45.041828  100
# 3     46.028327   72
# 4     46.037626  120
# ..          ...  ...
# 656  322.185369   60
# 657  372.813723   56
# 658  619.371177   76
# 659  738.370782   72
# 660  850.644746   68
#
# [661 rows x 2 columns]
#              mz   rt
# 0     44.980219   76
# 1     45.466507  112
# 2     50.014860   64
# 3     53.001897   68
# 4     53.038200  116
# ..          ...  ...
# 374  228.145636   60
# 375  233.079796   72
# 376  235.783147  368
# 377  252.415706   60
# 378  609.240314  112
#
# [379 rows x 2 columns]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
#             mz   rt
# 0    56.963392  192
# 1    58.014189   68
# 2    62.962030   56
# 3    68.981963   68
# 4    70.479288   64
# ..         ...  ...
# 60  179.074305   64
# 61  188.079056   76
# 62  190.038017   68
# 63  225.063541   68
# 64  768.487695   52
#
# [65 rows x 2 columns]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 213, in graph1
#     magnitude = filtered_df_1.values[0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 213, in graph1
#     magnitude = filtered_df_1.values[0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 213, in graph1
#     magnitude = filtered_df_1.values[0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 244, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Simulated spatial distribution/" + compound + ".png"
# TypeError: can only concatenate str (not "NoneType") to str
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 244, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Simulated spatial distribution/" + compound + ".png"
# TypeError: can only concatenate str (not "NoneType") to str
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 244, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/Simulated spatial distribution/" + compound + ".png"
# TypeError: can only concatenate str (not "NoneType") to str
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 261, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/HRMSMS/" + compound + ".csv"
# TypeError: can only concatenate str (not "NoneType") to str
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 261, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/HRMSMS/" + compound + ".csv"
# TypeError: can only concatenate str (not "NoneType") to str
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 261, in graph1
#     path = "C:/Users/Nikiforos/Desktop/Dash/Black_sea/Dash task_02 Feb 2022/Y2016/HRMSMS/" + compound + ".csv"
# TypeError: can only concatenate str (not "NoneType") to str
#               mz  rt
# 0      45.031289  64
# 1      46.037623  80
# 2      53.001730  72
# 3      55.017964  84
# 4      57.031872  84
# ...          ...  ..
# 2319  840.285385  64
# 2320  840.427234  84
# 2321  840.506869  52
# 2322  930.404751  60
# 2323  959.652677  60
#
# [2324 rows x 2 columns]
#              mz   rt
# 0     51.022200  108
# 1     53.037599  560
# 2     54.006129   88
# 3     54.040709   52
# 4     55.017105  380
# ..          ...  ...
# 585  259.144229   60
# 586  298.153928   56
# 587  337.189467   60
# 588  506.032909  144
# 589  798.988172   96
#
# [590 rows x 2 columns]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Nikiforos\anaconda3\envs\Thesis\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\NIKIFO~1\AppData\Local\Temp/ipykernel_3824/1796562306.py", line 193, in table
#     value = df["Feature"].tolist()[0]
# IndexError: list index out of range
#              mz   rt
# 0     46.064270   60
# 1     53.001665   64
# 2     53.037339   64
# 3     55.016951  156
# 4     55.054076  864
# ..          ...  ...
# 661  419.322188   56
# 662  449.286240   56
# 663  485.166856   60
# 664  561.940417  116
# 665  691.207886   56
#
# [666 rows x 2 columns]
#                mz      rt
# 0       45.003999      72
# 1       45.011891      60
# 2       45.022743      92
# 3       45.033446  103796
# 4       45.050373     360
# ...           ...     ...
# 2492  1067.488773      60
# 2493  1082.949526     124
# 2494  1091.926228      52
# 2495  1093.908658      60
# 2496  1185.234512      60
#
# [2497 rows x 2 columns]
#              mz   rt
# 0     45.031762   72
# 1     53.039773   60
# 2     55.052239  128
# 3     55.498334   56
# 4     57.033246  304
# ..          ...  ...
# 240  197.025391   88
# 241  203.056873   68
# 242  213.066264   56
# 243  224.933080   56
# 244  439.680054   64
#
# [245 rows x 2 columns]
#              mz    rt
# 0     45.031927    88
# 1     52.837483    52
# 2     55.016311    84
# 3     55.053363  1272
# 4     56.056192    68
# ..          ...   ...
# 606  288.994998    84
# 607  294.979404    56
# 608  302.206099    92
# 609  391.238995    56
# 610  560.881199    88
#
# [611 rows x 2 columns]
#                mz      rt
# 0       45.003999      72
# 1       45.011891      60
# 2       45.022743      92
# 3       45.033446  103796
# 4       45.050373     360
# ...           ...     ...
# 2492  1067.488773      60
# 2493  1082.949526     124
# 2494  1091.926228      52
# 2495  1093.908658      60
# 2496  1185.234512      60
#
# [2497 rows x 2 columns]
#                mz   rt
# 0       45.032753  552
# 1       45.044401  476
# 2       45.053984   72
# 3       45.518225   64
# 4       46.031361  108
# ...           ...  ...
# 3610  1103.784065   88
# 3611  1130.086395   52
# 3612  1136.710153   68
# 3613  1155.152131   56
# 3614  1183.974354   52
#
# [3615 rows x 2 columns]
#                mz   rt
# 0       45.017161   88
# 1       45.033357  332
# 2       45.043993  128
# 3       51.994320   52
# 4       53.000267   84
# ...           ...  ...
# 1705   813.868426   52
# 1706   872.538362   52
# 1707   960.604234   52
# 1708   988.624874   52
# 1709  1055.873573   64
#
# [1710 rows x 2 columns]
#                mz      rt
# 0       45.003999      72
# 1       45.011891      60
# 2       45.022743      92
# 3       45.033446  103796
# 4       45.050373     360
# ...           ...     ...
# 2492  1067.488773      60
# 2493  1082.949526     124
# 2494  1091.926228      52
# 2495  1093.908658      60
# 2496  1185.234512      60
#
# [2497 rows x 2 columns]
#                mz   rt
# 0       45.032753  552
# 1       45.044401  476
# 2       45.053984   72
# 3       45.518225   64
# 4       46.031361  108
# ...           ...  ...
# 3610  1103.784065   88
# 3611  1130.086395   52
# 3612  1136.710153   68
# 3613  1155.152131   56
# 3614  1183.974354   52
#
# [3615 rows x 2 columns]
#              mz   rt
# 0     45.031762   72
# 1     53.039773   60
# 2     55.052239  128
# 3     55.498334   56
# 4     57.033246  304
# ..          ...  ...
# 240  197.025391   88
# 241  203.056873   68
# 242  213.066264   56
# 243  224.933080   56
# 244  439.680054   64
#
# [245 rows x 2 columns]
#              mz   rt
# 0     45.038206  104
# 1     45.044785   92
# 2     45.052364  248
# 3     46.060631  104
# 4     46.305699   76
# ..          ...  ...
# 989  354.187662   52
# 990  360.258622   64
# 991  399.148837   72
# 992  401.281732   52
# 993  563.679490   60
#
# [994 rows x 2 columns]
#             mz   rt
# 0    44.980307  152
# 1    57.034325  112
# 2    57.041739   60
# 3    57.069865   64
# 4    58.030307   52
# 5    58.064624  172
# 6    67.055116   88
# 7    69.043184  108
# 8    69.073553   84
# 9    71.067582   56
# 10   78.299991   72
# 11   84.052899  108
# 12   85.037623   76
# 13   86.096338   88
# 14  112.074945   96
# 15  112.109471   64
# 16  113.071124  176
# 17  113.103531   88
# 18  113.120204   92
# 19  114.057111  168
# 20  114.091412  352
# 21  115.054846  172
# 22  115.085902  136
# 23  115.100641   84
# 24  115.125885   64
# 25  115.471001   64
# 26  122.026735  100
# 27  155.764406   60
# 28  197.393590  208
# 29  302.906454   84
# 30  450.499041   52
#               mz   rt
# 0      45.032102  120
# 1      45.037501  120
# 2      53.037475  244
# 3      53.994463   68
# 4      55.017206  368
# ..           ...  ...
# 543   587.968240   52
# 544   672.058212   76
# 545   918.734927   52
# 546  1029.021645   76
# 547  1184.898737   60
#
# [548 rows x 2 columns]
#              mz   rt
# 0     59.129739  112
# 1     60.043458   60
# 2     69.029081   88
# 3     80.947381  716
# 4     82.026599   88
# ..          ...  ...
# 170  264.178872   52
# 171  265.007685   60
# 172  265.087456   56
# 173  265.994410   56
# 174  271.032906   68
#
# [175 rows x 2 columns]
#                mz      rt
# 0       45.003999      72
# 1       45.011891      60
# 2       45.022743      92
# 3       45.033446  103796
# 4       45.050373     360
# ...           ...     ...
# 2492  1067.488773      60
# 2493  1082.949526     124
# 2494  1091.926228      52
# 2495  1093.908658      60
# 2496  1185.234512      60
#
# [2497 rows x 2 columns]
#                mz      rt
# 0       45.003999      72
# 1       45.011891      60
# 2       45.022743      92
# 3       45.033446  103796
# 4       45.050373     360
# ...           ...     ...
# 2492  1067.488773      60
# 2493  1082.949526     124
# 2494  1091.926228      52
# 2495  1093.908658      60
# 2496  1185.234512      60
#
# [2497 rows x 2 columns]
#              mz   rt
# 0     45.021196   96
# 1     45.032170  176
# 2     47.808783   60
# 3     53.038760  136
# 4     55.018928  144
# ..          ...  ...
# 98   152.022745   64
# 99   158.010394   68
# 100  167.441915  124
# 101  299.684477  120
# 102  418.444480   76
#
# [103 rows x 2 columns]
#               mz   rt
# 0      45.021708  112
# 1      45.033272  788
# 2      45.792336  108
# 3      45.822856   56
# 4      46.067286   56
# ...          ...  ...
# 1167  442.180736   60
# 1168  575.846927   72
# 1169  609.871761   64
# 1170  761.912989   64
# 1171  913.769781   64
#
# [1172 rows x 2 columns]
#                mz    rt
# 0       45.033422  5344
# 1       45.046519   196
# 2       45.108017    92
# 3       45.189666    76
# 4       45.252930    60
# ...           ...   ...
# 1657   673.059310   256
# 1658   718.136494    64
# 1659   838.371755    68
# 1660   893.480588    60
# 1661  1157.465384    68
#
# [1662 rows x 2 columns]
#               mz    rt
# 0      45.033438  4844
# 1      45.050027   128
# 2      45.309545    84
# 3      46.036866    92
# 4      52.312759    60
# ..           ...   ...
# 889   786.400354    76
# 890   814.651210    56
# 891   900.529085    56
# 892   944.147294   116
# 893  1013.825439    84
#
# [894 rows x 2 columns]
#                mz    rt
# 0       45.033456  1880
# 1       45.044354  3784
# 2       45.060575   108
# 3       45.117174    56
# 4       46.036699   108
# ...           ...   ...
# 3665  1107.373826    52
# 3666  1137.119256    68
# 3667  1152.362748    52
# 3668  1156.510980    52
# 3669  1186.503774    72
#
# [3670 rows x 2 columns]
#                mz   rt
# 0       45.033315  820
# 1       45.043954  888
# 2       45.084294   60
# 3       45.147472  100
# 4       45.970267   72
# ...           ...  ...
# 3794  1116.484183   64
# 3795  1132.670810   68
# 3796  1143.944269   56
# 3797  1147.220976   60
# 3798  1170.349707   64
#
# [3799 rows x 2 columns]
#              mz   rt
# 0     45.009099  224
# 1     45.015146  304
# 2     45.034301  240
# 3     45.051973  120
# 4     45.101373   56
# ..          ...  ...
# 115  242.205553   68
# 116  281.154232   56
# 117  434.524042   68
# 118  504.329389  100
# 119  569.253435   92
#
# [120 rows x 2 columns]
#             mz   rt
# 0    46.268633   96
# 1    55.053173  416
# 2    56.048993  652
# 3    56.963681   64
# 4    57.033475   88
# 5    57.050990   52
# 6    57.068676  204
# 7    58.063908  244
# 8    58.070968  176
# 9    59.046488  196
# 10   59.053317  152
# 11   60.392194   56
# 12   68.050016   72
# 13   69.062589   56
# 14   72.050287   92
# 15   72.080246   60
# 16   75.062216   60
# 17   77.061982   56
# 18   81.069773   64
# 19   83.046379  144
# 20   98.060887   64
# 21   98.071920  140
# 22  100.062122  124
# 23  100.069984   72
# 24  100.078699  240
# 25  101.080217   52
# 26  154.011539   60
# 27  166.045957  144
# 28  179.114978   64
# 29  228.462791   96
# 30  233.095371   64
#             mz    rt
# 0    45.035550   108
# 1    50.014732   432
# 2    51.021834  2004
# 3    52.026194    72
# 4    53.037565  2236
# ..         ...   ...
# 67  123.599007   124
# 68  143.084433   104
# 69  144.079705   232
# 70  145.081678    56
# 71  172.125119    60
#
# [72 rows x 2 columns]
#               mz   rt
# 0      44.997420   92
# 1      45.008926   84
# 2      45.015914  292
# 3      45.034801  116
# 4      45.190882   88
# ..           ...  ...
# 460   602.796103  104
# 461   732.831334   56
# 462   739.195628   60
# 463  1011.548814   96
# 464  1077.706242   56
#
# [465 rows x 2 columns]
#              mz   rt
# 0     45.021196   96
# 1     45.032170  176
# 2     47.808783   60
# 3     53.038760  136
# 4     55.018928  144
# ..          ...  ...
# 98   152.022745   64
# 99   158.010394   68
# 100  167.441915  124
# 101  299.684477  120
# 102  418.444480   76
#
# [103 rows x 2 columns]
#              mz   rt
# 0     45.032985   64
# 1     45.979562  104
# 2     52.018368   88
# 3     53.000803  308
# 4     53.036784   80
# ..          ...  ...
# 128  157.468715   56
# 129  170.434837   56
# 130  193.091387   56
# 131  672.047779   92
# 132  866.788255   64
#
# [133 rows x 2 columns]
#              mz    rt
# 0     45.034509   284
# 1     53.036828   132
# 2     54.039434    64
# 3     55.018197   192
# 4     55.053378  3420
# ..          ...   ...
# 108  161.021197    52
# 109  183.057697    52
# 110  184.125180    68
# 111  206.363354   100
# 112  625.123437    92
#
# [113 rows x 2 columns]
#              mz   rt
# 0     45.034225  112
# 1     45.051319  144
# 2     45.117131   56
# 3     45.579040   88
# 4     45.871917  100
# ..          ...  ...
# 863  547.657819   60
# 864  801.381202   60
# 865  840.994459   52
# 866  918.359490   88
# 867  979.611688   52
#
# [868 rows x 2 columns]
#              mz   rt
# 0     45.022401   80
# 1     45.032094  288
# 2     45.039942  128
# 3     53.039600   68
# 4     55.015946   56
# ..          ...  ...
# 242  172.110652  248
# 243  172.127997   56
# 244  173.116742   76
# 245  404.889935   56
# 246  662.838439   60
#
# [247 rows x 2 columns]
#              mz   rt
# 0     45.032518  196
# 1     47.011261  232
# 2     49.217479   68
# 3     53.035427   80
# 4     54.036320  100
# ..          ...  ...
# 264  190.047518  224
# 265  190.950495   68
# 266  191.013917   56
# 267  191.055179   52
# 268  222.128270   76
#
# [269 rows x 2 columns]
#              mz    rt
# 0     45.032917   188
# 1     51.023875    72
# 2     53.037541   160
# 3     55.017346   252
# 4     55.053507  1336
# ..          ...   ...
# 285  188.104503   200
# 286  188.116577   132
# 287  199.173651    68
# 288  340.759194    88
# 289  923.618351    52
#
# [290 rows x 2 columns]
#               mz   rt
# 0      45.032646  788
# 1      50.801420   80
# 2      51.721899   72
# 3      51.991456   76
# 4      53.002065   80
# ..           ...  ...
# 915   951.792487   52
# 916   983.203211   64
# 917   991.954820   56
# 918  1067.629374   60
# 919  1081.440884   76
#
# [920 rows x 2 columns]
#               mz   rt
# 0      45.033690  120
# 1      45.053547  112
# 2      53.036669   76
# 3      54.277152   60
# 4      55.016020   56
# ..           ...  ...
# 421   489.658343  124
# 422   503.304401   76
# 423   596.524368   60
# 424   717.448399   56
# 425  1039.552969   52
#
# [426 rows x 2 columns]
#               mz   rt
# 0      45.032864  968
# 1      45.051338   96
# 2      53.036734   80
# 3      55.017302   72
# 4      55.052222  136
# ..           ...  ...
# 536   243.051007   60
# 537   291.098886  100
# 538   634.483020   52
# 539   701.298000   52
# 540  1204.201039   84
#
# [541 rows x 2 columns]
#                mz   rt
# 0       45.035682  112
# 1       45.053446   64
# 2       45.154077  148
# 3       45.310942   68
# 4       46.008838   80
# ...           ...  ...
# 1636   752.335469   60
# 1637   790.858999   60
# 1638   952.186482   52
# 1639   964.855365   52
# 1640  1143.764798   52
#
# [1641 rows x 2 columns]
#               mz   rt
# 0      45.033502  124
# 1      47.649026   68
# 2      55.017845  900
# 3      55.052967  300
# 4      56.048580   96
# ..           ...  ...
# 786   257.136312   52
# 787   356.248862   60
# 788   373.096621   64
# 789   749.682262  136
# 790  1176.122138   80
#
# [791 rows x 2 columns]
#              mz   rt
# 0     55.017385   64
# 1     55.053364  620
# 2     55.063906   84
# 3     55.094454   72
# 4     56.046999   60
# ..          ...  ...
# 678  261.570359  112
# 679  263.125857   56
# 680  514.413510   56
# 681  584.650399   64
# 682  750.996795   56
#
# [683 rows x 2 columns]
#              mz   rt
# 0     45.031865  248
# 1     55.053092  276
# 2     56.048800   72
# 3     57.069152  520
# 4     57.090931  104
# ..          ...  ...
# 465  274.667422   76
# 466  294.945450   60
# 467  309.299395   76
# 468  402.191569   64
# 469  596.389456   56
#
# [470 rows x 2 columns]
#               mz   rt
# 0      45.021708  112
# 1      45.033272  788
# 2      45.792336  108
# 3      45.822856   56
# 4      46.067286   56
# ...          ...  ...
# 1167  442.180736   60
# 1168  575.846927   72
# 1169  609.871761   64
# 1170  761.912989   64
# 1171  913.769781   64
#
# [1172 rows x 2 columns]
#               mz   rt
# 0      45.033616  164
# 1      45.329353   64
# 2      46.063292   96
# 3      52.998790  104
# 4      53.037632  244
# ..           ...  ...
# 982   497.364572   60
# 983   499.180032   72
# 984   525.954984   88
# 985   664.499334   64
# 986  1136.757098   56
#
# [987 rows x 2 columns]
#               mz   rt
# 0      45.025046   52
# 1      45.034125  824
# 2      45.057060  280
# 3      46.039338   72
# 4      49.568588   80
# ..           ...  ...
# 877   889.424961   72
# 878   976.805145   72
# 879   996.825453   76
# 880  1057.588272   56
# 881  1128.723170   52
#
# [882 rows x 2 columns]
#               mz   rt
# 0      45.034480  208
# 1      47.036721   88
# 2      53.038191   76
# 3      55.024676   96
# 4      55.053281  284
# ...          ...  ...
# 1088  328.150655   60
# 1089  332.213930   56
# 1090  339.187173   52
# 1091  500.056206   60
# 1092  560.329689   68
#
# [1093 rows x 2 columns]
#               mz    rt
# 0      45.021114    72
# 1      45.033355  1800
# 2      45.046476   136
# 3      45.135595    60
# 4      46.036665   428
# ..           ...   ...
# 846   437.043905    60
# 847   447.412920    76
# 848   534.850607    60
# 849   661.213848   108
# 850  1080.448899    56
#
# [851 rows x 2 columns]
#                mz    rt
# 0       45.033352  3992
# 1       45.047585   140
# 2       45.052633   156
# 3       46.036797   284
# 4       47.038035    56
# ...           ...   ...
# 1236   494.287460    56
# 1237   562.362756    64
# 1238   623.796294    56
# 1239   738.071669    80
# 1240  1004.772698    64
#
# [1241 rows x 2 columns]
#               mz   rt
# 0      45.035083  136
# 1      53.036754   88
# 2      54.007411  104
# 3      55.018848  108
# 4      55.052114  240
# ..           ...  ...
# 816   673.445321   92
# 817   885.752272   60
# 818   950.468879  100
# 819   967.443276  112
# 820  1045.094568   72
#
# [821 rows x 2 columns]
#                mz   rt
# 0       45.034963  144
# 1       45.055377   96
# 2       53.005444   64
# 3       55.016442  268
# 4       55.053865  500
# ...           ...  ...
# 1334   504.113913   64
# 1335   523.051147   72
# 1336   578.332708   56
# 1337   619.628791   72
# 1338  1116.595640   60
#
# [1339 rows x 2 columns]
#                mz   rt
# 0       45.023719   96
# 1       45.032226  104
# 2       45.044772   56
# 3       55.017084  264
# 4       55.053272  664
# ...           ...  ...
# 1312   501.151841   68
# 1313   645.589096   56
# 1314   677.550608   84
# 1315   888.834229   64
# 1316  1087.798287   52
#
# [1317 rows x 2 columns]
#              mz    rt
# 0     45.033939   236
# 1     55.014617   100
# 2     55.054253   272
# 3     57.034494    56
# 4     57.069054  1204
# ..          ...   ...
# 804  597.544775    64
# 805  714.459923    60
# 806  721.502019    52
# 807  722.470962    52
# 808  958.031971    60
#
# [809 rows x 2 columns]
#               mz   rt
# 0      45.033220  320
# 1      47.036703   76
# 2      50.365166   52
# 3      52.999639   72
# 4      54.003078   88
# ..           ...  ...
# 857   702.212221   60
# 858   716.760725   60
# 859   721.064390   56
# 860   893.152063   64
# 861  1012.279594   56
#
# [862 rows x 2 columns]
#               mz    rt
# 0      45.033553  2100
# 1      46.036015   128
# 2      53.000714   200
# 3      54.004541    52
# 4      55.008666   120
# ..           ...   ...
# 780   610.519078    56
# 781   664.472733    60
# 782   671.330566    64
# 783   832.207391    52
# 784  1140.617747    68
#
# [785 rows x 2 columns]
#              mz   rt
# 0     45.029086   60
# ...
# 7     65.993259   72
# 8     79.018682   80
# 9    107.028478   64
# 10   142.033988   72
# 11   151.045730   72
# 12   180.027877   80
# 13   238.668321   72
# 14   602.561224   52
# 15   830.005467   80
# 16  1017.705247   56
#             mz   rt
# 0    56.224766   56
# 1    58.952957  408
# 2    59.952799  180
# 3    60.949603  228
# 4    74.931137   56
# 5    76.964038  128
# 6    77.965696   88
# 7    96.968846   56
# 8   104.970362   56
# 9   108.988728   68
# 10  112.987128  328
# 11  113.983424   96
# 12  114.981332  196
# 13  117.993862  132
# 14  123.044151   52
# 15  123.923968   64
# 16  127.000806  264
# 17  128.001782   72
# 18  128.961404  140
# 19  129.000241  208
# 20  130.994589  288
# 21  132.991812   52
# 22  136.002674  192
# 23  137.997832   64
# 24  141.013975   84
# 25  141.022011  124
# 26  141.051247   52
# 27  144.016743   68
# 28  145.036923   60
# 29  150.026088  112
# 30  152.010620   72
# 31  154.022775   56
# 32  155.028918   64
# 33  159.017052   92
# 34  175.626786   92
# 35  663.635004   52
#              mz    rt
# 0     45.036891   112
# 1     46.064629    68
# 2     51.020995   100
# 3     53.038186    72
# 4     58.065071   504
# 5     59.048102  2068
# 6     59.066525   112
# 7     60.053165   168
# 8     60.080624   104
# 9     62.058212   260
# 10    74.094196   276
# 11    76.073729    64
# 12    79.742488    52
# 13    86.058101   240
# 14    87.040879    60
# 15    94.285935    56
# 16   102.124592   184
# 17   103.071513    56
# 18   103.079452    92
# 19   104.112699   104
# 20   128.441033   108
# 21   377.104594    56
# 22  1072.456539    92
#             mz   rt
# 0    44.980307  152
# 1    57.034325  112
# 2    57.041739   60
# 3    57.069865   64
# 4    58.030307   52
# 5    58.064624  172
# 6    67.055116   88
# 7    69.043184  108
# 8    69.073553   84
# 9    71.067582   56
# 10   78.299991   72
# 11   84.052899  108
# 12   85.037623   76
# 13   86.096338   88
# 14  112.074945   96
# 15  112.109471   64
# 16  113.071124  176
# 17  113.103531   88
# 18  113.120204   92
# 19  114.057111  168
# 20  114.091412  352
# 21  115.054846  172
# 22  115.085902  136
# 23  115.100641   84
# 24  115.125885   64
# 25  115.471001   64
# 26  122.026735  100
# 27  155.764406   60
# 28  197.393590  208
# 29  302.906454   84
# 30  450.499041   52
#             mz    rt
# 0    45.033956   156
# 1    54.043433    84
# 2    55.017217  2936
# 3    55.053587   108
# 4    56.019866   156
# ..         ...   ...
# 90  162.006588    68
# 91  177.467945    68
# 92  179.016907    68
# 93  734.891813   152
# 94  892.847933    52
#
# [95 rows x 2 columns]
#               mz   rt
# 0      45.010664   52
# 1      45.031262  160
# 2      46.026113  128
# 3      46.060692  112
# 4      52.998280  152
# ..           ...  ...
# 117   204.435386   68
# 118   237.217319   56
# 119   453.561321   64
# 120   853.236433   68
# 121  1020.070095   84
#
# [122 rows x 2 columns]
#              mz   rt
# 0     45.034558  152
# 1     53.038300  116
# 2     55.018194  104
# 3     55.054929   72
# 4     58.028965   56
# ..          ...  ...
# 142  207.062936   56
# 143  209.045551   68
# 144  209.083012   56
# 145  210.078224   92
# 146  672.460014   84
#
# [147 rows x 2 columns]
#              mz    rt
# 0     53.002651   156
# 1     53.037720   160
# 2     54.068088    72
# 3     55.053501  6000
# 4     55.081543   104
# ..          ...   ...
# 167  161.071246    88
# 168  161.100329    80
# 169  219.063835   112
# 170  351.266390   100
# 171  982.231116    56
#
# [172 rows x 2 columns]
#              mz   rt
# 0     45.031762   72
# 1     53.039773   60
# 2     55.052239  128
# 3     55.498334   56
# 4     57.033246  304
# ..          ...  ...
# 240  197.025391   88
# 241  203.056873   68
# 242  213.066264   56
# 243  224.933080   56
# 244  439.680054   64
#
# [245 rows x 2 columns]
#              mz   rt
# 0     45.032863   84
# 1     53.038312   76
# 2     55.020439  108
# 3     55.053426  476
# 4     56.010486   56
# ..          ...  ...
# 186  181.052651  108
# 187  189.082604   56
# 188  190.045888   72
# 189  206.300784   64
# 190  634.525151   60
#
# [191 rows x 2 columns]
#               mz   rt
# 0      45.031672   80
# 1      53.038134  184
# 2      55.015976  108
# 3      55.053669  136
# 4      56.049989   60
# ..           ...  ...
# 363   508.793032   56
# 364   725.861573   60
# 365   764.571234   60
# 366   917.986463   56
# 367  1147.367033   76
#
# [368 rows x 2 columns]
#               mz   rt
# 0      45.032102  120
# 1      45.037501  120
# 2      53.037475  244
# 3      53.994463   68
# 4      55.017206  368
# ..           ...  ...
# 543   587.968240   52
# 544   672.058212   76
# 545   918.734927   52
# 546  1029.021645   76
# 547  1184.898737   60
#
# [548 rows x 2 columns]
#              mz    rt
# 0     45.032949   340
# 1     54.030769    80
# 2     55.016373   228
# 3     55.053189  1112
# 4     57.033208    88
# ..          ...   ...
# 402  204.182979   124
# 403  206.117080    72
# 404  214.102185    68
# 405  216.091210    60
# 406  298.298588    88
#
# [407 rows x 2 columns]
#              mz    rt
# 0     45.031927    88
# 1     52.837483    52
# 2     55.016311    84
# 3     55.053363  1272
# 4     56.056192    68
# ..          ...   ...
# 606  288.994998    84
# 607  294.979404    56
# 608  302.206099    92
# 609  391.238995    56
# 610  560.881199    88
#
# [611 rows x 2 columns]
#              mz   rt
# 0     45.034302  352
# 1     46.036660   84
# 2     55.015196  132
# 3     55.053033  360
# 4     56.054321   56
# ..          ...  ...
# 508  271.146432   56
# 509  278.429933   60
# 510  298.545675  108
# 511  338.274407   72
# 512  453.151915   60
#
# [513 rows x 2 columns]
#              mz   rt
# 0     45.033031   52
# 1     53.038263   52
# 2     55.052365   88
# 3     56.048539  148
# 4     57.034862   68
# ..          ...  ...
# 601  390.414405   80
# 602  425.028793   56
# 603  427.926590   72
# 604  490.751429   68
# 605  657.092951   52
#
# [606 rows x 2 columns]
#              mz   rt
# 0     45.034515  240
# 1     46.039403   56
# 2     55.052472   88
# 3     56.048071   92
# 4     56.058798   60
# ..          ...  ...
# 581  302.196836  164
# 582  303.199730   68
# 583  307.806988   68
# 584  403.652390  148
# 585  424.322398   60
#
# [586 rows x 2 columns]
#              mz   rt
# 0     45.033323   56
# 1     53.036739  104
# 2     55.017383  112
# 3     55.052655  180
# 4     56.056673  112
# ..          ...  ...
# 517  331.146546   72
# 518  342.265530   64
# 519  343.662878   56
# 520  357.273947   52
# 521  481.259458   52
#
# [522 rows x 2 columns]
#               mz   rt
# 0      45.033834  344
# 1      45.085601  100
# 2      53.037605  860
# 3      54.040826  112
# 4      55.014520   92
# ..           ...  ...
# 783   616.368900   68
# 784  1004.021635   68
# 785  1113.794151   60
# 786  1135.072288   76
# 787  1153.521342   76
#
# [788 rows x 2 columns]
#              mz   rt
# 0     45.038206  104
# 1     45.044785   92
# 2     45.052364  248
# 3     46.060631  104
# 4     46.305699   76
# ..          ...  ...
# 989  354.187662   52
# 990  360.258622   64
# 991  399.148837   72
# 992  401.281732   52
# 993  563.679490   60
#
# [994 rows x 2 columns]
#                mz   rt
# 0       45.032819  280
# 1       46.063505  148
# 2       47.070502  172
# 3       48.066731   80
# 4       54.042224   64
# ...           ...  ...
# 1114   394.277920   68
# 1115   869.717103  100
# 1116   880.878743   52
# 1117  1033.213437   80
# 1118  1152.206028  308
#
# [1119 rows x 2 columns]
#                mz     rt
# 0       45.012175     60
# 1       45.024003     88
# 2       45.033510  19916
# 3       45.056874    164
# 4       45.141123     64
# ...           ...    ...
# 1249   622.147812     56
# 1250   792.121447     56
# 1251  1028.537755     56
# 1252  1045.507923     64
# 1253  1060.222589     76
#
# [1254 rows x 2 columns]
#                mz    rt
# 0       45.034217   140
# 1       46.061930    68
# 2       55.017184   388
# 3       55.053087  1436
# 4       55.068272    52
# ...           ...   ...
# 1119   445.533282    72
# 1120   801.365506    64
# 1121   895.285643    56
# 1122  1074.512318    56
# 1123  1101.805462    60
#
# [1124 rows x 2 columns]
#               mz   rt
# 0      45.030411   68
# 1      45.035677   52
# 2      45.043558   96
# 3      47.011278   64
# 4      49.737170  116
# ...          ...  ...
# 1353  402.259609   56
# 1354  449.143262   72
# 1355  529.651143   68
# 1356  560.013729  100
# 1357  570.750335   56
#
# [1358 rows x 2 columns]
#              mz   rt
# 0     57.068410  184
# 1     72.048196  120
# 2     91.054218  576
# 3    102.968033   64
# 4    105.070186  376
# ..          ...  ...
# 758  552.788390   72
# 759  552.857497   76
# 760  646.805074   64
# 761  892.396936   60
# 762  892.437897   64
#
# [763 rows x 2 columns]
#               mz    rt
# 0      45.033305  2744
# 1      45.046610   136
# 2      45.300422    56
# 3      46.036174   132
# 4      53.038276    76
# ...          ...   ...
# 1202  454.274900    60
# 1203  461.121676    60
# 1204  491.746356    60
# 1205  563.339455    60
# 1206  831.496121    68
#
# [1207 rows x 2 columns]
#                mz   rt
# 0       45.035302  172
# 1       45.043689  120
# 2       55.016184   92
# 3       55.053150  388
# 4       56.056058   80
# ...           ...  ...
# 1415   468.084118   68
# 1416   533.393181   80
# 1417   544.215515   56
# 1418   971.484985   60
# 1419  1191.074977   64
#
# [1420 rows x 2 columns]
#               mz   rt
# 0      55.017238  196
# 1      55.052548   56
# 2      57.072435   80
# 3      58.061934   56
# 4      61.036505   68
# ..           ...  ...
# 894   499.311949   92
# 895   573.371687   52
# 896   590.033074   68
# 897  1021.273198   80
# 898  1149.255036  104
#
# [899 rows x 2 columns]
#                mz     rt
# 0       45.033358  27400
# 1       45.057919     84
# 2       45.146111     52
# 3       45.189576     52
# 4       45.423065     60
# ...           ...    ...
# 1447   588.504794     52
# 1448   617.731901     64
# 1449   646.704844    196
# 1450   701.407137     56
# 1451  1085.078896    100
#
# [1452 rows x 2 columns]
#                mz     rt
# 0       44.998754     88
# 1       45.033212  25912
# 2       45.080298    100
# 3       45.101364     56
# 4       45.111378     72
# ...           ...    ...
# 2434   868.133551     56
# 2435   936.660385     52
# 2436   953.905076     56
# 2437  1050.741805    108
# 2438  1130.824217    104
#
# [2439 rows x 2 columns]
#              mz    rt
# 0     45.023726    68
# 1     45.033064  2364
# 2     45.052652   120
# 3     46.037563   252
# 4     46.066819    96
# ..          ...   ...
# 871  538.914893    56
# 872  624.359537    52
# 873  639.369880    56
# 874  639.389629    76
# 875  703.495231    60
#
# [876 rows x 2 columns]
#               mz   rt
# 0      55.053293  108
# 1      57.068640   92
# 2      59.046942   76
# 3      60.057879  100
# 4      69.065386   76
# ..           ...  ...
# 688   602.357814  136
# 689   609.294557   64
# 690   810.644418   72
# 691  1020.637946   64
# 692  1186.111963   52
#
# [693 rows x 2 columns]
#              mz   rt
# 0     45.032904  176
# 1     55.055205  104
# 2     57.066998  300
# 3     57.296639   72
# 4     58.072723  120
# ..          ...  ...
# 650  547.396451   52
# 651  587.321405   60
# 652  591.341658   52
# 653  602.368113   64
# 654  767.151938   80
#
# [655 rows x 2 columns]
#                mz   rt
# 0       45.984921   56
# 1       50.137410   52
# 2       53.005430   88
# 3       53.039677  100
# 4       54.031970  112
# ...           ...  ...
# 3118  1094.285810   68
# 3119  1115.600261   72
# 3120  1131.813365   56
# 3121  1195.723644   60
# 3122  1202.115729   92
#
# [3123 rows x 2 columns]
#                mz   rt
# 0       45.039584  108
# 1       45.771197   72
# 2       46.267102   52
# 3       50.740083   68
# 4       53.036829   72
# ...           ...  ...
# 3155  1174.186404   72
# 3156  1177.916428   52
# 3157  1186.754504   56
# 3158  1195.276480   52
# 3159  1202.272240   56
#
# [3160 rows x 2 columns]
#               mz   rt
# 0      45.033723  388
# 1      53.997585   60
# 2      55.053715  988
# 3      55.064169  108
# 4      56.056062   92
# ...          ...  ...
# 1231  742.568969   56
# 1232  781.184298   88
# 1233  829.656757   88
# 1234  839.735175  124
# 1235  867.649639   52
#
# [1236 rows x 2 columns]
#               mz   rt
# 0      45.033012  144
# 1      45.040903  148
# 2      55.052366  128
# 3      56.055896   88
# 4      57.031478   80
# ...          ...  ...
# 1248  584.338686   60
# 1249  652.415184   64
# 1250  668.415663   64
# 1251  702.228506   52
# 1252  777.337654   52
#
# [1253 rows x 2 columns]
#                mz   rt
# 0       45.033061  192
# 1       55.016187   84
# 2       55.051070  140
# 3       57.070108  192
# 4       59.047113   68
# ...           ...  ...
# 2062   751.954853   88
# 2063   839.530919   52
# 2064   887.463906   52
# 2065   903.556495   60
# 2066  1125.652748   72
#
# [2067 rows x 2 columns]
#               mz   rt
# 0      51.043543   88
# 1      53.038313  268
# 2      55.017909  196
# 3      55.053913  240
# 4      57.032606  180
# ...          ...  ...
# 2918  821.285685   56
# 2919  839.419167   52
# 2920  895.435440   64
# 2921  900.597793   56
# 2922  931.428508   64
#
# [2923 rows x 2 columns]
#                mz   rt
# 0       45.017161   88
# 1       45.033357  332
# 2       45.043993  128
# 3       51.994320   52
# 4       53.000267   84
# ...           ...  ...
# 1705   813.868426   52
# 1706   872.538362   52
# 1707   960.604234   52
# 1708   988.624874   52
# 1709  1055.873573   64
#
# [1710 rows x 2 columns]
#            mz   rt
# 0   45.013216   56
# 1   65.012530   72
# 2   98.425454  284
# 3  182.969079   56
# 4  279.824777   76
#                mz   rt
# 0       45.032753  552
# 1       45.044401  476
# 2       45.053984   72
# 3       45.518225   64
# 4       46.031361  108
# ...           ...  ...
# 3610  1103.784065   88
# 3611  1130.086395   52
# 3612  1136.710153   68
# 3613  1155.152131   56
# 3614  1183.974354   52
#
# [3615 rows x 2 columns]
#               mz   rt
# 0      45.035149  672
# 1      45.320943   60
# 2      45.593128   64
# 3      45.647392   92
# 4      45.883389   52
# ...          ...  ...
# 2095  914.597835   52
# 2096  916.560571   64
# 2097  940.534194   56
# 2098  947.581883   64
# 2099  991.916158   52
#
# [2100 rows x 2 columns]
#               mz    rt
# 0      45.033857   400
# 1      51.024179    84
# 2      53.038509    64
# 3      54.974059    96
# 4      55.016927  3720
# ...          ...   ...
# 2114  882.076509    68
# 2115  882.594690    52
# 2116  893.257860    56
# 2117  898.619367    52
# 2118  909.437737    52
#
# [2119 rows x 2 columns]
#            mz   rt
# 0   72.079339   64
# 1   74.028995  104
# 2   74.103208   92
# 3   81.545446   56
# 4  116.838142   80
# 5  300.648205   96
#               mz   rt
# 0      45.034467  240
# 1      45.044281  132
# 2      55.016795  512
# 3      55.024007  100
# 4      55.053090   76
# ...          ...  ...
# 1667  882.612804   52
# 1668  941.632472   68
# 1669  948.162686   56
# 1670  969.571987   60
# 1671  975.555372   52
#
# [1672 rows x 2 columns]
#               mz   rt
# 0      55.053306   60
# 1      57.033082  132
# 2      59.048366  864
# 3      60.052795   56
# 4      63.331152   96
# ...          ...  ...
# 1265  953.715870   52
# 1266  982.567636  116
# 1267  982.593973   96
# 1268  983.595601   84
# 1269  983.706360   60
#
# [1270 rows x 2 columns]
#             mz     rt
# 0    52.055358     56
# 1    54.032022     60
# 2    55.027621     72
# 3    55.178909     76
# 4    56.048712   7448
# 5    57.051405    324
# 6    68.037341     80
# 7    81.047862     64
# 8    83.060312  13408
# 9    83.080674     96
# 10   83.091193    128
# 11   83.457821     56
# 12   84.063194    564
# 13   84.670628     56
# 14   84.802315     56
# 15   85.078643     68
# 16   87.259717     84
# 17  213.835868     80
# 18  463.398182    104
#            mz   rt
# 0   53.038298  212
# 1   55.054106  176
# 2   56.046915  128
# 3   56.960226   56
# 4   57.068243   60
# 5   67.054800   72
# 6   83.050256   56
# 7  201.192196   96
# 8  538.195357   84
# 9  849.626118   52
#             mz   rt
# 0    56.963382  188
# 1    58.959275   80
# 2    60.957035   76
# 3    86.992372   56
# 4   104.999413   88
# 5   105.007583   64
# 6   106.996817   92
# 7   114.043880   76
# 8   119.017127   52
# 9   121.018012   80
# 10  123.011899  848
# 11  124.012910  232
# 12  125.011873   88
# 13  137.029915  144
# 14  138.030766   52
# 15  138.987884  112
# 16  142.992543   56
# 17  146.027877  276
# 18  146.631341   52
# 19  147.026577   56
# 20  163.042064   60
# 21  192.055724   52
# 22  401.336840   56
#             mz   rt
# 0    58.952975  168
# 1    60.948462  132
# 2    62.979366   72
# 3   112.981425  164
# 4   114.977395   60
# 5   125.013202   64
# 6   126.996250   60
# 7   127.008462   80
# 8   130.992591   52
# 9   135.997508   68
# 10  137.993530  148
# 11  142.978854   68
#               mz    rt
# 0      45.033672   156
# 1      55.017264    92
# 2      56.970511    92
# 3      57.034386   280
# 4      57.068967  1016
# ...          ...   ...
# 1297  933.351482    56
# 1298  937.505209    52
# 1299  950.378010    60
# 1300  955.290094    52
# 1301  959.504298    72
#
# [1302 rows x 2 columns]
